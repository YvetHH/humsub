# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import os, glob

# %%
def concat_benchmark(input_dir):
    output_df = pd.DataFrame()
    for file in glob.glob(f"{input_dir}/*.txt"):
        sample = file.split("/")[-1].strip(".txt")
        df = pd.read_csv(file, sep='\t')
        df['sample'] = sample
        output_df = pd.concat([output_df,df])
    output_df = output_df.set_index("sample")
    return output_df

# %%
metaphlan = concat_benchmark("runtime/metaphlan/")

sourmash_sketch = concat_benchmark("runtime/sourmash/sketching/")
sourmash_gather = concat_benchmark("runtime/sourmash/gather/")

sourmash_total = sourmash_gather + sourmash_sketch

sourmash_total['tool'] = 'sourmash'
metaphlan['tool'] = 'metaphlan'

# %%
total_performance = pd.concat([sourmash_total,metaphlan])

# %%
total_performance = total_performance.reset_index()

# %%
total_performance
# Out:
#      sample         s           h:m:s   max_rss   max_vms   max_uss   max_pss  \
# 0   sample8  350.5952  0:02:570:02:53   5829.07   6104.84   5734.95   5756.62
# 1   sample9  365.4936  0:03:140:02:51   5424.27   5623.49   5279.29   5325.80
# 2   sample7  412.8846  0:03:590:02:53   8770.60   8977.76   8747.34   8751.11
# 3   sample6  340.0010  0:02:450:02:54   4446.03   4642.84   4291.42   4329.38
# 4   sample4  380.1232  0:03:250:02:54   7576.60   7797.89   7423.32   7472.02
# 5   sample5  349.5090  0:02:560:02:52   6044.87   6255.28   6023.34   6026.70
# 6   sample1  365.7566  0:03:110:02:53   5550.70   5800.12   5394.22   5442.81
# 7   sample0  311.6456  0:02:170:02:54   4969.77   5174.61   4815.37   4845.85
# 8   sample2  361.3461  0:03:060:02:54   5497.69   5689.01   5336.56   5387.27
# 9   sample3  392.2785  0:03:370:02:55   7236.24   7449.01   7080.03   7128.19
# 10  sample8  433.4895         0:07:13  17780.85  19222.33  17736.34  17750.44
# 11  sample9  444.5563         0:07:24  17613.59  19078.32  17571.93  17577.60
# 12  sample7  446.1254         0:07:26  17666.82  19126.33  17622.72  17629.18
# 13  sample6  442.6323         0:07:22  17694.88  19126.46  17674.30  17676.92
# 14  sample4  415.4804         0:06:55  17691.48  19126.46  17672.08  17674.63
# 15  sample5  425.2255         0:07:05  17659.88  19126.46  17617.38  17623.48
# 16  sample1  462.1346         0:07:42  17619.47  19078.58  17576.80  17586.36
# 17  sample0  422.3367         0:07:02  17773.28  19222.34  17728.34  17742.37
# 18  sample2  383.9150         0:06:23  17690.50  19126.33  17671.21  17674.09
# 19  sample3  460.6442         0:07:40  17761.86  19222.48  17720.05  17729.05
#
#        io_in  io_out  mean_load  cpu_time       tool
# 0    2232.99    0.76     181.09    317.54   sourmash
# 1    2150.18    0.75     176.07    320.55   sourmash
# 2    2056.66    0.76     185.30    382.61   sourmash
# 3    2044.51    0.75     171.54    292.02   sourmash
# 4    2079.82    0.76     185.24    352.31   sourmash
# 5    2205.27    0.76     184.50    322.35   sourmash
# 6    2131.90    0.75     176.62    322.15   sourmash
# 7    2196.75    0.75     188.17    292.17   sourmash
# 8    2037.60    0.75     178.47    321.97   sourmash
# 9    2062.61    0.76     179.99    352.33   sourmash
# 10  17690.23   40.99     533.80     51.02  metaphlan
# 11  17677.17   41.52     545.60     73.72  metaphlan
# 12  17653.60   38.56     541.98     71.11  metaphlan
# 13  17705.78   41.10     520.17     78.24  metaphlan
# 14  17707.82   38.98     516.95     68.93  metaphlan
# 15  17690.07   43.62     568.18     61.91  metaphlan
# 16  17670.46   34.88     559.19     54.06  metaphlan
# 17  17683.10   24.02     516.38     60.35  metaphlan
# 18  17702.19   40.99     501.48     68.30  metaphlan
# 19  17658.01   42.79     565.10     56.75  metaphlan

# %%
ORDER = ['metaphlan','sourmash']

# %%
sns.set_context('paper')
fig,ax = plt.subplots(figsize=(6,8))
sns.boxplot(data = total_performance, x='tool',y='s',ax=ax,color='lightgray', linewidth=1.5,order=ORDER)
sns.swarmplot(data = total_performance, x='tool',y='s',ax=ax,s=10,hue='sample',order=ORDER)
sns.lineplot(x="tool", y="s", hue='sample', data=total_performance,estimator=None, legend=False)
#plt.title('L2 distance between reference and test abundances from HumGut MAGs.')
plt.xlabel("")
plt.ylabel("Runtime [s]",fontsize=28)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.set_xticklabels(['MetaPhlAn4\n [8 cores]','Sourmash with \nsubspecies catalog'])

ax.get_legend().remove()
plt.savefig("runtime.svg")

# %%
sns.set_context('paper')
fig,ax = plt.subplots(figsize=(6,8))
sns.boxplot(data = total_performance, x='tool',y='max_uss',ax=ax,color='lightgray', linewidth=1.5,order=ORDER)
sns.swarmplot(data = total_performance, x='tool',y='max_uss',ax=ax,s=10,hue='sample',order=ORDER)
sns.lineplot(x="tool", y="max_uss", hue='sample', data=total_performance,estimator=None, legend=False)
#plt.title('L2 distance between reference and test abundances from HumGut MAGs.')
plt.xlabel("")
plt.ylabel("Total memory [MB]",fontsize=28)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.set_xticklabels(['MetaPhlAn4\n [8 cores]','Sourmash with \nsubspecies catalog'])
ax.get_legend().remove()
